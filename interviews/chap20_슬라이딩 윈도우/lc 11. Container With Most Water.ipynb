# %% [markdown]
# ## lc 11. Container With Most Water
# ---
#
# You are given an integer array height of length n. There are n vertical lines drawn such that the two endpoints of the ith line are (i, 0) and (i, height[i]).
#
# Find two lines that together with the x-axis form a container, such that the container contains the most water.
#
# Return the maximum amount of water a container can store.
#
# Notice that you may not slant the container.

# %%
from urllib.request import urlopen
from PIL import Image

url ='https://s3-lc-upload.s3.amazonaws.com/uploads/2018/07/17/question_11.jpg'
img = Image.open(urlopen(url))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=801x383 at 0x2700CF9D400>

# %% [markdown]
#     put: height = [1,8,6,2,5,4,8,3,7]
#     Output: 49
#     Explanation: The above vertical lines are represented by array [1,8,6,2,5,4,8,3,7]. In this case, the max area of water (blue section) the container can contain is 49.

# %% [markdown]
# ### Solution 01

# %%
class Solution(object):
    def maxArea(height):
        """
        :type height: List[int]
        :rtype: int
        """
        
        ans, i, j = 0, 0, len(height)-1
        while (i < j):
            if height[i] <= height[j]:
                res = height[i] * (j - i)
                i += 1
            else:
                res = height[j] * (j - i)
                j -= 1
            if res > ans: 
                ans = res
        return ans

# %%
height = [1,8,6,2,5,4,8,3,7]
Solution.maxArea(height)
# Out:
# 49

# %% [markdown]
# Runtime: 767 ms, faster than 64.38% of Python online submissions for Container With Most Water.
# Memory Usage: 23.9 MB, less than 77.34% of Python online submissions for Container With Most Water.
